# %% [markdown]
# Media outlets are consistently on the lookout for new and upcoming players, regardless of sport. Young talent, valiant comebacks, rise after injury or any combination of the latter generate consistent media coverage, followed by support for that player and love for the sport. For instance, Serena Williams has grown both fame and worldwide support through her distinguished and transformative career as a tennis icon. She has changed the game through her triumphs and unprecedented adversities. Throughout her career, she has won thousands of dollars in prizes and has been breaking tennis records for decades. In our project, we will be analysing statistics from current tennis players, including their prize sums and the number of seasons they have been playing. We will be creating a classification model to predict a player's global ranking based on how many seasons they’ve played and their total prize money. This in turn will help officials classify a player who is new to the league in comparison to the veterans. The dataset that we have obtained was retrieved from “canvas” and consists of several columns, however our focus will be placed upon “Prize Money” and ”Seasons” to predict current rank. This will not only be important for media outlets looking for their next rising star, but for advertisors looking for their next sponsorship, or the average "joe" looking to place a $5 bet on who they think is going to win the match.

# %% [markdown]
# Firstly, we are reading the necessary packages for our plots and functions for our regression model. These include ggplot2 and tidyverse.

# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(GGally)
library(ISLR)
options(repr.matrix.max.rows = 6)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.0     ✔ rsample      1.0.0
# ✔ dials        1.0.0     ✔ tune         1.0.0
# ✔ infer        1.0.2     ✔ workflows    1.0.0
# ✔ modeldata    1.0.0     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.0     ✔ yardstick    1.0.0
# ✔ recipes      1.0.1
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ...

# %% [markdown]
# To read our data, we have tidyed most of it outside of Jupyter as this was more efficient. We have titled our raw data "player_data_initial". Below, we had to ensure that the column names were representative of the information, so those were renamed accoridngly. We have subsequently filtered for the players current rank. total seasons, and prize money.
#
# After the filter, we have placed 75% of our data into training and 25% to testing, with the predictor being "current rank"

# %%
player_data_initial <- read_csv("https://raw.githubusercontent.com/pangus3/DSCI-Group-Project/main/data/player_stats.csv")
player_data_initial

#Reading in our player data after it has been tidyed on excel.
# Out:
# New names:
# • `` -> `...1`
# Rows: 500 Columns: 38
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (25): Age, Country, Plays, Wikipedia, Current Rank, Best Rank, Name, Bac...
# dbl (13): ...1, Turned Pro, Seasons, Titles, Best Season, Retired, Masters, ...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     ...1 Age             Country        Plays        Wikipedia Current Rank
# 1   0    26 (25-04-1993) Brazil         Right-handed Wikipedia 378
# 2   1    18 (22-12-2001) United Kingdom Left-handed  Wikipedia 326
# 3   2    32 (03-11-1987) Slovakia       Right-handed Wikipedia 178
# ⋮   ⋮    ⋮               ⋮              ⋮            ⋮         ⋮
# 498 497  23 (14-03-1996) Netherlands    Left-handed  Wikipedia 495
# 499 498  24 (17-05-1995) Ukraine        NA           Wikipedia 419
# ...

# %% [markdown]
# We then need to select only the categories we need from this dataset. The variables we need are prize money and seasons, in order to find the predictor, current rank.

# %%
colnames(player_data_initial) <- make.names(colnames(player_data_initial), unique=TRUE)
player_data_edited <- player_data_initial |>
mutate(current_rank = as.integer(Current.Rank)) |>
mutate(prize_money = as.integer(Prize.Money)) |>
select(Seasons, current_rank, prize_money) |>
as_tibble()


player_data <- player_data_edited |>
filter(!is.na(Seasons),!is.na(current_rank), !is.na(prize_money) )
player_data

#The data read in was then edited to change the column name and types (to integers), select the three columns we want, and filter out any values that were not existent
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”
#     Seasons current_rank prize_money
# 1   14      178          3261567
# 2    2      236           374093
# 3   11      183          6091971
# ⋮   ⋮       ⋮            ⋮
# 361  1      397             40724
# 362 10        5          22132368
# 363  2      451             61984

# %%
player_data
#Splitting the data into the training and testing sets, with 75% of the data going to training, and 25% of it going to testing. 
player_split <- initial_split(player_data, prop = 0.75, strata = current_rank)  
player_train<- training(player_split)   
player_test<- testing(player_split)
# Out:
#     Seasons current_rank prize_money
# 1   14      178          3261567
# 2    2      236           374093
# 3   11      183          6091971
# ⋮   ⋮       ⋮            ⋮
# 361  1      397             40724
# 362 10        5          22132368
# 363  2      451             61984

# %%
#Building a model specification (player_spec) to specify the model and training algorithm. 
player_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
      set_engine("kknn") |>
       set_mode("regression") 
player_spec
# Out:
# K-Nearest Neighbor Model Specification (regression)
#
# Main Arguments:
#   neighbors = tune()
#   weight_func = rectangular
#
# Computational engine: kknn

# %%
#Recipe specifies the predictors/response and preprocesses the data, so it’s scaled. 
player_recipe <- recipe(current_rank ~ Seasons + prize_money, data = player_train) |>
       step_scale(all_predictors()) |>
       step_center(all_predictors())
player_recipe
# Out:
# Recipe
#
# Inputs:
#
#       role #variables
#    outcome          1
#  predictor          2
#
# Operations:
#
# Scaling for all_predictors()
# Centering for all_predictors()

# %%
#creating the fold for cross-validation. Cross validation uses a structured splitting so that each observation is used in a validation set only once
player_vfold<-  vfold_cv(player_train, v = 5, strata = current_rank)

#The workflow combines the model and recipe
player_workflow <- workflow() |>
       add_recipe(player_recipe) |>
   add_model(player_spec)

# %%
gridvals <- tibble(neighbors= c(1:100))
player_results <- player_workflow |>
       tune_grid(resamples = player_vfold, grid = gridvals) |>
collect_metrics()
player_results

#We are collecting data on what is the best "k" value to use, as in how many closest neighbors our model should use in order to garner the most accurate predictions.
# Out:
#     neighbors .metric .estimator mean        n std_err
# 1   1         rmse    standard   129.4802957 5 6.06616108
# 2   1         rsq     standard     0.2612883 5 0.05018847
# 3   2         rmse    standard   116.7267487 5 2.89487842
# ⋮   ⋮         ⋮       ⋮          ⋮           ⋮ ⋮
# 198  99       rsq     standard     0.2721312 5 0.04488534
# 199 100       rmse    standard   117.7392088 5 3.77065009
# 200 100       rsq     standard     0.2694546 5 0.04503442
#     .config
# 1   Preprocessor1_Model001
# 2   Preprocessor1_Model001
# 3   Preprocessor1_Model002
# ⋮   ⋮
# 198 Preprocessor1_Model099
# 199 Preprocessor1_Model100
# 200 Preprocessor1_Model100

# %%
player_min<- player_results |>
    filter(.metric == "rmse") |>
  arrange(mean) |> 
    slice(1)

player_min

#The ideal number of neighbors would be 10.
# Out:
#   neighbors .metric .estimator mean     n std_err  .config
# 1 10        rmse    standard   106.5118 5 5.343387 Preprocessor1_Model010

# %%
k_min <-player_min |>
      pull(neighbors)

player_best_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = k_min) |>
         set_engine("kknn") |>
          set_mode("regression")

player_best_fit <- workflow() |>
         add_recipe(player_recipe) |>
          add_model(player_best_spec) |>
          fit(data = player_train)

player_summary <- player_best_fit |>
         predict(player_test) |>
           bind_cols(player_test) |>
           metrics(truth = current_rank, estimate = .pred)


player_summary
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   105.3716193
# 2 rsq     standard     0.3791137
# 3 mae     standard    85.9293478

# %% [markdown]
# Above is a table with the metric, the estimator and the estimation. “RMSE” is the Root Mean Square Error, and generally we want to obtain lower values for this metric. In our worksheet, we had examples of 160 and 175, so we came to the consensus that our value of approximately 105 was feasible and our models predictions will be close to actual values. Rmse is representative of the average distance between the actual value and the value the model has generated, and in some sense can be used as a “goodness of fit” metric
# Rsq, or R squared, is 1- (Sum of squares residual / Total sum of squares). This is a metric for variance, and is telling of how much of the variance in our dependent variables are caused by the regression model. In our case, our R^2 value of 0.35 approximately tells us that 35% of our variance in the dependent variable can be explained by our model.
# Finally, we have mae, which stands for Mean Absolute Error. MAE takes the absolute value, so there is no preference as to which direction an error lies (whether it is an over or under estimation of the predicted vs actual values.) Generally, we would have hoped to obtain a lower mae value, as to indicate closer to 0 difference, also meaning that the models predictions were closer to the actual values.

# %%
#Predicting a new players rank given their prize money and seasons of tennis played
#In this cell, we have chosen a new player called Jack Black from Mars. We want to analyze his statistics to see if he is someone worth betting on, or someone that the media should be covering as a new successful player. 

new_player_stats <- tibble(Seasons = 3, 
                            prize_money=145563)

#This recipe is using all the player data this time to create the model recipe instead of just the trianing.. but it is using the same spec that found the best k!
player_recipe_all_data <- recipe(current_rank ~ Seasons + prize_money, data = player_data) |>
                        step_scale(all_predictors()) |>
                        step_center(all_predictors())
                     
player_fit_all_data <- workflow() |>
          add_recipe(player_recipe_all_data) |>
          add_model(player_best_spec) |>
          fit(data = player_data)

new_player_predicted <- predict(player_fit_all_data, new_player_stats)

new_player_predicted

#The result underneath '.pred' is the predicted rank of Jack Black based off our model and player data using Seasons played and Prize Money Recieved
#The current rank that we were able to find makes sense with our varibles. Jack Black is placed at about middle to lower end of the pack at a rank of 300.
#That being said we would recommend that media outlets keep an eye on Jack Black as he has only played for 3 seasons and is already ranking towards the middle of the pack. We suggest that sponsors buy in now and those looking to place bets, bet on Jack as an average ranking is not high risk for a bet.
# Out:
#   .pred
# 1 300

# %%
options(repr.plot.width = 20, repr.plot.height = 20) 
jackblack <- c(300, 145563)
player_plot <- player_data |>
    ggplot(aes(x = current_rank, y = prize_money, color = Seasons)) +
    geom_point() +
    labs(x = "Current Rank", y = "Prize Money Recieved($)", color = "Seasons Played") +
    ggtitle("Tennis Player Current Rank based on Prize Money Received and Seasons played") +
geom_point(size = 1.5) + 
scale_y_continuous( trans= 'log10')+
       annotate("text", x = 300, y =  145563, label = "JB", size = 6) +
   theme(text = element_text(size = 18))

player_plot

#This plot is able to tell us what everyone's current rank is if we look at the variables of how many seasons they have played and how much prize money they have earned. 
#The JB represents where Jack Black would fall in this data based off the ranking we generated and the prize money and seasons we used to generate it.
# Out:
# plot without title

# %% [markdown]
# Discussion:
# We have found that the new player entering this league of tennis would be ranked 300. This tells us that if he joined this particular league of tennis, this is where he would fall. We did somewhat expect the new player, Jack Black, to be at this rank, we had predicted that he would fall somewhere in the middle. We predicted this because even though Jack Black had played very few seasons, he had made a decent amount of money during them, proving that he is middle to low good. Since Jack Black did not have as much experience under his belt like a lot of the people in the new league, it would make sense that he would fall in the middle of the ranks. Even though this all makes sense, we could have never predicted this exact rank, which is why we needed to use R.
# These findings could impact the world of tennis and the world of sports in general. We figured out that we are able to predict what the current rank of a player new to a league would be, based on how many seasons other players in this league have played and how much prize money they have earned. The current rank predictor could be helpful to up and coming players who are curious as to what position they would fall in. Additionally it would be helpful for media, sponsors, and the average viewer to see where a player ranks in order to decide where to allocate their time and money.
#
# Some future questions could be:
#
# Is the current rank going to be completely accurate?
# Will the new player be guaranteed to get signed based on his predicted standing?
# Are we able to use different variables to predict the same thing (current rank)?

# %% [markdown]
# References:
# 1. “5 Three Variables: Data Visualization in R with ggplot2.” Social Science Computing Cooperative, sscc.wisc.edu/sscc/pubs/dvr/three-variables.html. Accessed 18 June 2023.
# 2. “How to Add Circles around Specific Data Points in R.” GeeksforGeeks, 17 Oct. 2021, www.geeksforgeeks.org/how-to-add-circles-around-specific-data-points-in-r/.
# 3. “Scatter Plots - R Base Graphs.” STHDA, www.sthda.com/english/wiki/scatter-plots-r-base-graphs. Accessed 25 June 2023.
# 4. Ultimate Tennis Statistics, www.ultimatetennisstatistics.com/. Accessed 15 June 2023.
